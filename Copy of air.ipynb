# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#!pip install xgboost
import xgboost
from dateutil.relativedelta import relativedelta
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

root_path = 'gdrive/MyDrive/Colab Notebooks/'
path = Path(root_path)
filename = 'av.csv'

df_final = pd.read_csv(path/filename)
df_final
# Out:
#                   date    PM10      NO     NO2  ...    SO2     NH3 Toluene    PM25
# 0     01-01-2019 00:00  752.78  179.68  111.66  ...  10.79   93.35   58.33  492.03
# 1     01-01-2019 08:00  408.19  135.13  148.64  ...  13.86   104.4   31.63  266.16
# 2     01-01-2019 16:00  475.85  123.27  177.02  ...  21.74   89.24   89.25   382.5
# 3     02-01-2019 00:00  771.27  357.61  106.05  ...   5.99  109.64   99.34  545.28
# 4     02-01-2019 08:00  495.06    75.6  125.28  ...  19.54  108.53   57.46  344.22
# ...                ...     ...     ...     ...  ...    ...     ...     ...     ...
# 2123  08-12-2020 16:00  426.88  263.38  117.48  ...  37.45   58.13  152.52  233.56
# 2124  09-12-2020 00:00  407.25  341.16   75.62  ...  16.91   58.52  220.12  330.22
# 2125  09-12-2020 08:00  353.31   56.12    87.8  ...  23.87   36.83   61.83  301.69
# 2126  09-12-2020 16:00  314.28  118.58   48.84  ...   None   21.07   83.18  182.78
# 2127  10-12-2020 00:00     261   23.75    27.4  ...   None   21.65   22.45     201
#
# [2128 rows x 13 columns]

# %%
df_final = df_final.mask(df_final.eq('None')).dropna()

df_final.drop('date', inplace=True, axis=1)
df_final['PM10'] = df_final['PM10'].astype(float)
df_final['NO'] = df_final['NO'].astype(float)
df_final['NO2'] = df_final['NO2'].astype(float)
df_final['WS'] = df_final['WS'].astype(float)
df_final['CO'] = df_final['CO'].astype(float)
df_final['Benzene'] = df_final['Benzene'].astype(float)
df_final['NOx'] = df_final['NOx'].astype(float)
df_final['Ozone'] = df_final['Ozone'].astype(float)
df_final['SO2'] = df_final['SO2'].astype(float)
df_final['NH3'] = df_final['NH3'].astype(float)
df_final['Toluene'] = df_final['Toluene'].astype(float)
df_final['PM25'] = df_final['PM25'].astype(float)


#df_final['date'] = pd.to_datetime(df_final['date'])
df_final
# Out:
#         PM10      NO     NO2    WS    CO  ...  Ozone    SO2     NH3  Toluene    PM25
# 0     752.78  179.68  111.66  0.30  3.52  ...  22.86  10.79   93.35    58.33  492.03
# 1     408.19  135.13  148.64  0.53  4.57  ...  22.68  13.86  104.40    31.63  266.16
# 2     475.85  123.27  177.02  0.31  5.66  ...  26.04  21.74   89.24    89.25  382.50
# 3     771.27  357.61  106.05  0.30  5.96  ...  61.84   5.99  109.64    99.34  545.28
# 4     495.06   75.60  125.28  1.13  1.56  ...  34.37  19.54  108.53    57.46  344.22
# ...      ...     ...     ...   ...   ...  ...    ...    ...     ...      ...     ...
# 2120  437.81  299.69  121.05  0.30  6.01  ...  15.17  22.77   54.00    99.99  279.81
# 2121  384.05  390.43   66.77  0.30  4.65  ...  15.00  12.56   53.33   147.88  342.25
# 2122  265.54   53.14  122.93  0.31  2.28  ...  40.43  19.62   60.17    19.02  235.23
# 2123  426.88  263.38  117.48  0.30  4.29  ...  16.23  37.45   58.13   152.52  233.56
# 2125  353.31   56.12   87.80  0.31  2.48  ...  26.99  23.87   36.83    61.83  301.69
#
# [1728 rows x 12 columns]

# %%
print(df_final.dtypes)
# Out:
# PM10       float64
# NO         float64
# NO2        float64
# WS         float64
# CO         float64
# Benzene    float64
# NOx        float64
# Ozone      float64
# SO2        float64
# NH3        float64
# Toluene    float64
# PM25       float64
# dtype: object

# %%
df_final.columns
#df_final['date'].max() 
#df_final.date.min()
# Out:
# Index(['PM10', 'NO', 'NO2', 'WS', 'CO', 'Benzene', 'NOx', 'Ozone', 'SO2',
#        'NH3', 'Toluene', 'PM25'],
#       dtype='object')

# %%
features = ['PM10', 'NO', 'NO2', 'WS', 'CO', 'Benzene', 'NOx', 'Ozone','SO2', 'NH3', 'Toluene', 'PM25']

# %%
from sklearn.model_selection import train_test_split
X, y = df_final.iloc[:,:-1],df_final.iloc[:,-1]
trainX, testX, trainy, testy = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
model = xgboost.XGBRegressor(objective='count:poisson', n_estimators=1000, learning_rate=0.002, max_depth=4, alpha=5)
model.fit(trainX,trainy)
pred = model.predict(testX)
MAE= mean_absolute_error(testy, pred)
MSE= mean_squared_error(testy, pred)
RMSE = np.sqrt(mean_squared_error(testy, pred))
print("Mean Absolute Error: %f" % (MAE))
#print("Mean Square Error: %f" % (MSE))
print("Root Mean Square Error: %f" % (RMSE))
# Out:
# Mean Absolute Error: 24.026664
# Root Mean Square Error: 38.964915

# %%
params = {"objective":"count:poisson",'colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 5, 'alpha': 10}
data_dmatrix = xgboost.DMatrix(data=X,label=y)

cv_results = xgboost.cv(dtrain=data_dmatrix, params=params, nfold=3,
                    num_boost_round=50,early_stopping_rounds=10,metrics="rmse", as_pandas=True, seed=123)
cv_results.head()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0       155.533463        2.309550      155.479792       4.693015
# 1       155.504766        2.309526      155.451070       4.692984
# 2       155.473989        2.309506      155.420309       4.692988
# 3       155.440938        2.309495      155.387278       4.692991
# 4       155.405619        2.309477      155.351883       4.692957

# %%
print((cv_results["test-rmse-mean"]).tail(1))
# Out:
# 49    144.05307
# Name: test-rmse-mean, dtype: float64

# %%
model = xgboost.train(params=params, dtrain=data_dmatrix, num_boost_round=10)
import matplotlib.pyplot as plt

xgboost.plot_tree(model,num_trees=0)
plt.rcParams['figure.figsize'] = [50, 10]
plt.show()

# %%
xgboost.plot_importance(model._Booster)
plt.rcParams['figure.figsize'] = [50, 10]
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-fce6a6480503> in <module>()
# ----> 1 xgboost.plot_importance(model._Booster)
#       2 plt.rcParams['figure.figsize'] = [50, 10]
#       3 plt.show()
#
# AttributeError: 'Booster' object has no attribute '_Booster'

# %%
from sklearn import preprocessing

result=preprocessing.normalize(df_final, axis=0)
result
