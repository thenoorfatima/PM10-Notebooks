# %% [markdown]
# #**We employ the following models:**
#
# 1. CNN
# 2. LSTM
# 3. BiLSTM
# 4. GRU
#
# #Hybrid
# 5. CNN-LSTM
# 6. CNN-BiLSTM
# 7. CNN-GRU

# %% [markdown]
# #**IMPORTS**

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential, Model
from tensorflow.python.keras.layers.convolutional import Conv1D, MaxPooling1D
from tensorflow.python.keras.layers import Dense, LSTM, RepeatVector 
from tensorflow.keras.layers import TimeDistributed, Flatten

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.offline as py #visualization
py.init_notebook_mode(connected=True) #visualization
import plotly.graph_objs as go #visualization
import plotly.tools as tls #visualization
import plotly.figure_factory as ff
from plotly.offline import init_notebook_mode, iplot

# %matplotlib inline
warnings.filterwarnings("ignore")
init_notebook_mode(connected=True)

# Set seeds to make the experiment more reproducible.
from tensorflow.compat.v1 import set_random_seed
from numpy.random import seed
set_random_seed(1)
seed(1)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file = 'drive/MyDrive/Colab Notebooks/b2.csv'
raw_data = pd.read_csv(file, parse_dates = ['date'], index_col = 'date')

df = raw_data.copy()
print(df.head())
# Out:
#             PM2dot5    PM10     NO    NO2    NOx    NH3    SO2    CO  Ozone  \
# date
# 2019-01-01   151.12  515.67  56.88  54.95  75.44  74.42  18.54  2.51  27.43
# 2019-01-02   257.21  625.60  58.90  73.14  86.91  81.71  21.16  3.00  31.07
# 2019-01-03   141.07  515.14  22.73  44.50  42.12  75.25  16.18  2.02  17.08
# 2019-01-04   222.49  383.30  18.52  36.10  34.29  53.20  15.61  1.88  12.88
# 2019-01-05   309.92  494.91  18.40  58.23  45.92  49.80  15.43  2.10   3.63
#
#             Wind speed
# date
# 2019-01-01        0.64
# 2019-01-02        0.84
# 2019-01-03        0.97
# 2019-01-04        0.80
# 2019-01-05        1.33

# %% [markdown]
# #**EDA & Preprocessing**

# %%
df.describe()
# Out:
#            PM2dot5        PM10           NO          NO2          NOx  \
# count  1026.000000  996.000000  1028.000000  1028.000000  1028.000000
# mean    118.970955  229.700748     9.980272    32.364110    26.534018
# std      94.117334  138.305529    13.281891    22.964907    19.223764
# min      13.450000   12.040000     0.450000     1.840000     3.660000
# 25%      51.985000  119.867500     2.287500    16.027500    12.647500
# 50%      87.720000  204.040000     4.480000    27.520000    20.095000
# 75%     160.025000  311.057500    11.387500    42.680000    34.560000
# max     703.000000  810.940000    89.760000   188.580000   123.310000
#
#                NH3          SO2           CO        Ozone  Wind speed
# count  1032.000000  1016.000000  1025.000000  1026.000000  365.000000
# mean     36.012524    11.248100     1.164990    38.311676    1.177671
# std      18.258039     7.584875     0.652307    22.022606    0.407871
# min       0.040000     1.260000     0.190000     3.500000    0.500000
# 25%      23.152500     5.365000     0.730000    21.580000    0.900000
# 50%      31.970000     8.980000     1.020000    33.110000    1.110000
# 75%      44.295000    16.000000     1.460000    52.045000    1.390000
# max     121.590000    39.640000     5.900000   114.590000    3.030000

# %%
# Define a function to draw time_series plot
def timeseries (x_axis, y_axis, x_label, y_label):
    plt.figure(figsize = (10, 6))
    plt.plot(x_axis, y_axis, color ='blue')
    plt.xlabel(x_label, {'fontsize': 12})
    plt.ylabel(y_label, {'fontsize': 12})

timeseries(df.index, df['PM10'], 'Time (day)', 'PM10')

# %%
def plot_histogram(x):
    plt.hist(x, bins = 19, alpha=0.8, color = 'blue', edgecolor = 'black')
    plt.title("Histogram of '{var_name}'".format(var_name=x.name))
    plt.xlabel("Value")
    plt.ylabel("Frequency")

plot_histogram(df['PM10'])

# %%
#RENAME
#df = df.rename(columns = {'Max Temp (C)':'Max_T', 'Min Temp (C)':'Min_T','Total Precip (mm)':'T_P','WC (m3/capita.day)':'UWC'})

# Missing values
df.isnull().sum()
# Out:
# PM2dot5         9
# PM10           39
# NO              7
# NO2             7
# NOx             7
# NH3             3
# SO2            19
# CO             10
# Ozone           9
# Wind speed    670
# dtype: int64

# %%
# Replace missing values by interpolation
def replace_missing (attribute):
    return attribute.interpolate(inplace=True)

replace_missing(df['PM2dot5'])
replace_missing(df['PM10'])
replace_missing(df['NO'])
replace_missing(df['NO2'])
replace_missing(df['NOx'])
replace_missing(df['NH3'])
replace_missing(df['SO2'])
replace_missing(df['CO'])
replace_missing(df['Ozone'])
replace_missing(df['Wind speed'])

# %%
# Outlier detection
up_b = df['PM10'].mean() + 2*df['PM10'].std()
low_b = df['PM10'].mean() - 2*df['PM10'].std()

# Replace outlier by interpolation for base consumption
df.loc[df['PM10'] > up_b, 'PM10'] = np.nan
df.loc[df['PM10'] < low_b, 'PM10'] = np.nan
df['PM10'].interpolate(inplace=True)

# %% [markdown]
# ## Train/validation split

# %%
train_size = int(len(df)*0.8)
train_dataset, test_dataset = df.iloc[:train_size], df.iloc[train_size:]

# Plot train and test data
plt.figure(figsize = (10, 6))
plt.plot(train_dataset.PM10)
plt.plot(test_dataset.PM10)
plt.xlabel('Time (day)')
plt.ylabel('PM 10 values')
plt.legend(['Train set', 'Test set'], loc='upper right')
#plt.savefig('C:/Users/nious/Documents/Medium/LSTM&GRU/2.jpg', format='jpg', dpi=1000)

print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)
# Out:
# Dimension of train data:  (828, 10)
# Dimension of test data:  (207, 10)

# %%
X_train = train_dataset.drop('PM10', axis = 1)
y_train = train_dataset.loc[:,['PM10']]

X_valid = test_dataset.drop('PM10', axis = 1)
y_valid = test_dataset.loc[:,['PM10']]

# %%
# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))

# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)

# Apply the scaler to test data
valid_y_norm = output_scaler.transform(y_valid)
valid_x_norm = input_scaler.transform(X_valid)

# %%
def create_dataset (X, Y, time_steps = 1):
    Xs, ys = [], []
    
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(Y[i+time_steps])
        
    return np.array(Xs), np.array(ys)


TIME_STEPS = 30

X_valid, Y_valid = create_dataset(valid_x_norm, valid_y_norm, TIME_STEPS)
X_train, Y_train = create_dataset(train_x_norm, train_y_norm, TIME_STEPS)
print('X_train.shape: ', X_valid.shape)
print('Y_train.shape: ', Y_train.shape)
print('X_valid.shape: ', X_valid.shape) 
print('Y_valid.shape: ', Y_train.shape)
# Out:
# X_train.shape:  (177, 30, 9)
# Y_train.shape:  (798, 1)
# X_valid.shape:  (177, 30, 9)
# Y_valid.shape:  (798, 1)

# %% [markdown]
# #**MODEL TRAINING**

# %% [markdown]
# #1. CNN
#
# * For the CNN model we will use one convolutional hidden layer followed by a max pooling layer. The filter maps are then flattened before being interpreted by a Dense layer and outputting a prediction.
# * The convolutional layer should be able to identify patterns between the timesteps.
# * Input shape **[samples, timesteps, features]**.
#
# #### Data preprocess
# * Reshape from [samples, timesteps] into [samples, timesteps, features].
# * This same reshaped data will be used on the CNN and the LSTM model.

# %%
epochs = 40
batch = 256
lr = 0.0003
adam = optimizers.Adam(lr)

# %%
X_train_series = X_train.reshape(798,30,9)
X_valid_series = X_valid.reshape(177,30,9)
print('Train set shape', X_train_series.shape)
print('Validation set shape', X_valid_series.shape)
# Out:
# Train set shape (798, 30, 9)
# Validation set shape (177, 30, 9)

# %%
model_cnn = Sequential()
model_cnn.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(train_x_norm.shape[1], train_x_norm.shape[1])))
model_cnn.add(MaxPooling1D(pool_size=2))
model_cnn.add(Flatten())
model_cnn.add(Dense(50, activation='relu'))
model_cnn.add(Dense(1))
model_cnn.compile(loss='mse', optimizer=adam)
#model_cnn.summary()

# %%
cnn_history = model_cnn.fit(X_train_series, Y_train, validation_data=(X_valid_series, Y_valid), epochs=epochs, verbose=2)
# Out:
# Epoch 1/40
# 25/25 - 1s - loss: 0.0976 - val_loss: 0.0295 - 1s/epoch - 47ms/step
# Epoch 2/40
# 25/25 - 0s - loss: 0.0489 - val_loss: 0.0269 - 134ms/epoch - 5ms/step
# Epoch 3/40
# 25/25 - 0s - loss: 0.0433 - val_loss: 0.0286 - 127ms/epoch - 5ms/step
# Epoch 4/40
# 25/25 - 0s - loss: 0.0399 - val_loss: 0.0315 - 149ms/epoch - 6ms/step
# Epoch 5/40
# 25/25 - 0s - loss: 0.0369 - val_loss: 0.0264 - 166ms/epoch - 7ms/step
# Epoch 6/40
# 25/25 - 0s - loss: 0.0338 - val_loss: 0.0271 - 154ms/epoch - 6ms/step
# Epoch 7/40
# 25/25 - 0s - loss: 0.0314 - val_loss: 0.0301 - 134ms/epoch - 5ms/step
# Epoch 8/40
# 25/25 - 0s - loss: 0.0285 - val_loss: 0.0276 - 143ms/epoch - 6ms/step
# Epoch 9/40
# 25/25 - 0s - loss: 0.0264 - val_loss: 0.0297 - 131ms/epoch - 5ms/step
# Epoch 10/40
# 25/25 - 0s - loss: 0.0242 - val_loss: 0.0317 - 138ms/epoch - 6ms/step
# Epoch 11/40
# 25/25 - 0s - loss: 0.0228 - val_loss: 0.0286 - 135ms/epoch - 5ms/step
# Epoch 12/40
# 25/25 - 0s - loss: 0.0220 - val_loss: 0.0288 - 124ms/epoch - 5ms/step
# Epoch 13/40
# 25/25 - 0s - loss: 0.0208 - val_loss: 0.0263 - 130ms/epoch - 5ms/step
# Epoch 14/40
# 25/25 - 0s - loss: 0.0197 - val_loss: 0.0348 - 133ms/epoch - 5ms/step
# Epoch 15/40
# 25/25 - 0s - loss: 0.0189 - val_loss: 0.0263 - 137ms/epoch - 5ms/step
# Epoch 16/40
# 25/25 - 0s - loss: 0.0177 - val_loss: 0.0288 - 138ms/epoch - 6ms/step
# Epoch 17/40
# 25/25 - 0s - loss: 0.0172 - val_loss: 0.0287 - 127ms/epoch - 5ms/step
# Epoch 18/40
# 25/25 - 0s - loss: 0.0160 - val_loss: 0.0293 - 136ms/epoch - 5ms/step
# Epoch 19/40
# 25/25 - 0s - loss: 0.0155 - val_loss: 0.0256 - 133ms/epoch - 5ms/step
# Epoch 20/40
# 25/25 - 0s - loss: 0.0158 - val_loss: 0.0269 - 135ms/epoch - 5ms/step
# Epoch 21/40
# 25/25 - 0s - loss: 0.0140 - val_loss: 0.0263 - 125ms/epoch - 5ms/step
# Epoch 22/40
# 25/25 - 0s - loss: 0.0136 - val_loss: 0.0278 - 134ms/epoch - 5ms/step
# Epoch 23/40
# 25/25 - 0s - loss: 0.0134 - val_loss: 0.0275 - 134ms/epoch - 5ms/step
# Epoch 24/40
# 25/25 - 0s - loss: 0.0126 - val_loss: 0.0250 - 125ms/epoch - 5ms/step
# Epoch 25/40
# 25/25 - 0s - loss: 0.0118 - val_loss: 0.0247 - 133ms/epoch - 5ms/step
# Epoch 26/40
# 25/25 - 0s - loss: 0.0122 - val_loss: 0.0289 - 137ms/epoch - 5ms/step
# Epoch 27/40
# 25/25 - 0s - loss: 0.0119 - val_loss: 0.0256 - 129ms/epoch - 5ms/step
# Epoch 28/40
# 25/25 - 0s - loss: 0.0113 - val_loss: 0.0241 - 144ms/epoch - 6ms/step
# Epoch 29/40
# 25/25 - 0s - loss: 0.0111 - val_loss: 0.0251 - 131ms/epoch - 5ms/step
# Epoch 30/40
# 25/25 - 0s - loss: 0.0104 - val_loss: 0.0251 - 142ms/epoch - 6ms/step
# Epoch 31/40
# 25/25 - 0s - loss: 0.0102 - val_loss: 0.0266 - 125ms/epoch - 5ms/step
# Epoch 32/40
# 25/25 - 0s - loss: 0.0096 - val_loss: 0.0259 - 123ms/epoch - 5ms/step
# Epoch 33/40
# 25/25 - 0s - loss: 0.0093 - val_loss: 0.0265 - 135ms/epoch - 5ms/step
# Epoch 34/40
# 25/25 - 0s - loss: 0.0090 - val_loss: 0.0233 - 129ms/epoch - 5ms/step
# Epoch 35/40
# 25/25 - 0s - loss: 0.0089 - val_loss: 0.0242 - 160ms/epoch - 6ms/step
# Epoch 36/40
# 25/25 - 0s - loss: 0.0087 - val_loss: 0.0242 - 140ms/epoch - 6ms/step
# Epoch 37/40
# 25/25 - 0s - loss: 0.0079 - val_loss: 0.0252 - 133ms/epoch - 5ms/step
# Epoch 38/40
# 25/25 - 0s - loss: 0.0078 - val_loss: 0.0257 - 129ms/epoch - 5ms/step
# Epoch 39/40
# 25/25 - 0s - loss: 0.0076 - val_loss: 0.0236 - 118ms/epoch - 5ms/step
# Epoch 40/40
# 25/25 - 0s - loss: 0.0073 - val_loss: 0.0236 - 143ms/epoch - 6ms/step

# %% [markdown]
# #2. LSTM
#
# * Now the LSTM model actually sees the input data as a sequence, so it's able to learn patterns from sequenced data (assuming it exists) better than the other ones, especially patterns from long sequences.
# * Input shape **[samples, timesteps, features]**.

# %%
model_lstm = Sequential()
model_lstm.add(LSTM(50, activation='relu', input_shape=(X_train_series.shape[1], X_train_series.shape[2])))
model_lstm.add(Dense(1))
model_lstm.compile(loss='mse', optimizer=adam)
#model_lstm.summary()

# %%
lstm_history = model_lstm.fit(X_train_series, Y_train, validation_data=(X_valid_series, Y_valid), epochs=epochs, verbose=2)
# Out:
# Epoch 1/40
# 25/25 - 4s - loss: 0.0960 - val_loss: 0.0279 - 4s/epoch - 158ms/step
# Epoch 2/40
# 25/25 - 1s - loss: 0.0431 - val_loss: 0.0246 - 810ms/epoch - 32ms/step
# Epoch 3/40
# 25/25 - 1s - loss: 0.0377 - val_loss: 0.0220 - 839ms/epoch - 34ms/step
# Epoch 4/40
# 25/25 - 1s - loss: 0.0355 - val_loss: 0.0222 - 803ms/epoch - 32ms/step
# Epoch 5/40
# 25/25 - 1s - loss: 0.0338 - val_loss: 0.0204 - 814ms/epoch - 33ms/step
# Epoch 6/40
# 25/25 - 1s - loss: 0.0330 - val_loss: 0.0203 - 843ms/epoch - 34ms/step
# Epoch 7/40
# 25/25 - 1s - loss: 0.0320 - val_loss: 0.0222 - 818ms/epoch - 33ms/step
# Epoch 8/40
# 25/25 - 1s - loss: 0.0317 - val_loss: 0.0207 - 819ms/epoch - 33ms/step
# Epoch 9/40
# 25/25 - 1s - loss: 0.0297 - val_loss: 0.0202 - 804ms/epoch - 32ms/step
# Epoch 10/40
# 25/25 - 1s - loss: 0.0290 - val_loss: 0.0205 - 814ms/epoch - 33ms/step
# Epoch 11/40
# 25/25 - 1s - loss: 0.0285 - val_loss: 0.0209 - 826ms/epoch - 33ms/step
# Epoch 12/40
# 25/25 - 1s - loss: 0.0288 - val_loss: 0.0214 - 825ms/epoch - 33ms/step
# Epoch 13/40
# 25/25 - 1s - loss: 0.0274 - val_loss: 0.0203 - 791ms/epoch - 32ms/step
# Epoch 14/40
# 25/25 - 1s - loss: 0.0267 - val_loss: 0.0222 - 795ms/epoch - 32ms/step
# Epoch 15/40
# 25/25 - 1s - loss: 0.0257 - val_loss: 0.0217 - 788ms/epoch - 32ms/step
# Epoch 16/40
# 25/25 - 1s - loss: 0.0247 - val_loss: 0.0265 - 785ms/epoch - 31ms/step
# Epoch 17/40
# 25/25 - 1s - loss: 0.0240 - val_loss: 0.0218 - 829ms/epoch - 33ms/step
# Epoch 18/40
# 25/25 - 1s - loss: 0.0239 - val_loss: 0.0236 - 808ms/epoch - 32ms/step
# Epoch 19/40
# 25/25 - 1s - loss: 0.0232 - val_loss: 0.0233 - 824ms/epoch - 33ms/step
# Epoch 20/40
# 25/25 - 1s - loss: 0.0231 - val_loss: 0.0233 - 864ms/epoch - 35ms/step
# Epoch 21/40
# 25/25 - 1s - loss: 0.0216 - val_loss: 0.0227 - 813ms/epoch - 33ms/step
# Epoch 22/40
# 25/25 - 1s - loss: 0.0217 - val_loss: 0.0250 - 821ms/epoch - 33ms/step
# Epoch 23/40
# 25/25 - 1s - loss: 0.0218 - val_loss: 0.0229 - 815ms/epoch - 33ms/step
# Epoch 24/40
# 25/25 - 1s - loss: 0.0205 - val_loss: 0.0236 - 827ms/epoch - 33ms/step
# Epoch 25/40
# 25/25 - 1s - loss: 0.0203 - val_loss: 0.0228 - 813ms/epoch - 33ms/step
# Epoch 26/40
# 25/25 - 1s - loss: 0.0202 - val_loss: 0.0244 - 807ms/epoch - 32ms/step
# Epoch 27/40
# 25/25 - 1s - loss: 0.0204 - val_loss: 0.0236 - 814ms/epoch - 33ms/step
# Epoch 28/40
# 25/25 - 1s - loss: 0.0201 - val_loss: 0.0245 - 822ms/epoch - 33ms/step
# Epoch 29/40
# 25/25 - 1s - loss: 0.0205 - val_loss: 0.0238 - 805ms/epoch - 32ms/step
# Epoch 30/40
# 25/25 - 1s - loss: 0.0192 - val_loss: 0.0240 - 800ms/epoch - 32ms/step
# Epoch 31/40
# 25/25 - 1s - loss: 0.0197 - val_loss: 0.0261 - 797ms/epoch - 32ms/step
# Epoch 32/40
# 25/25 - 1s - loss: 0.0193 - val_loss: 0.0239 - 841ms/epoch - 34ms/step
# Epoch 33/40
# 25/25 - 1s - loss: 0.0191 - val_loss: 0.0244 - 832ms/epoch - 33ms/step
# Epoch 34/40
# 25/25 - 1s - loss: 0.0192 - val_loss: 0.0257 - 829ms/epoch - 33ms/step
# Epoch 35/40
# 25/25 - 1s - loss: 0.0189 - val_loss: 0.0252 - 846ms/epoch - 34ms/step
# Epoch 36/40
# 25/25 - 1s - loss: 0.0189 - val_loss: 0.0243 - 788ms/epoch - 32ms/step
# Epoch 37/40
# 25/25 - 1s - loss: 0.0184 - val_loss: 0.0278 - 809ms/epoch - 32ms/step
# Epoch 38/40
# 25/25 - 1s - loss: 0.0185 - val_loss: 0.0249 - 832ms/epoch - 33ms/step
# Epoch 39/40
# 25/25 - 1s - loss: 0.0190 - val_loss: 0.0237 - 821ms/epoch - 33ms/step
# Epoch 40/40
# 25/25 - 1s - loss: 0.0181 - val_loss: 0.0244 - 823ms/epoch - 33ms/step

# %% [markdown]
# #3. BiLSTM

# %%
# BiLSTM model
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional 

model_bilstm = Sequential()
model_bilstm.add(Bidirectional(LSTM(50, activation='relu', input_shape=(X_train_series.shape[1], X_train_series.shape[2]))))
model_bilstm.add(Dense(y_train.shape[1]))

model_bilstm.compile(loss='mse', optimizer='adam')

# %%
bilstm_history = model_bilstm.fit(X_train_series, Y_train, validation_data=(X_valid_series, Y_valid), epochs=epochs, verbose=2)
# Out:
# Epoch 1/40
# 25/25 - 3s - loss: 0.1104 - val_loss: 0.0294 - 3s/epoch - 134ms/step
# Epoch 2/40
# 25/25 - 1s - loss: 0.0464 - val_loss: 0.0272 - 628ms/epoch - 25ms/step
# Epoch 3/40
# 25/25 - 1s - loss: 0.0421 - val_loss: 0.0271 - 581ms/epoch - 23ms/step
# Epoch 4/40
# 25/25 - 1s - loss: 0.0379 - val_loss: 0.0282 - 592ms/epoch - 24ms/step
# Epoch 5/40
# 25/25 - 1s - loss: 0.0347 - val_loss: 0.0231 - 576ms/epoch - 23ms/step
# Epoch 6/40
# 25/25 - 1s - loss: 0.0322 - val_loss: 0.0227 - 594ms/epoch - 24ms/step
# Epoch 7/40
# 25/25 - 1s - loss: 0.0296 - val_loss: 0.0226 - 596ms/epoch - 24ms/step
# Epoch 8/40
# 25/25 - 1s - loss: 0.0273 - val_loss: 0.0233 - 587ms/epoch - 23ms/step
# Epoch 9/40
# 25/25 - 1s - loss: 0.0257 - val_loss: 0.0243 - 602ms/epoch - 24ms/step
# Epoch 10/40
# 25/25 - 1s - loss: 0.0234 - val_loss: 0.0213 - 568ms/epoch - 23ms/step
# Epoch 11/40
# 25/25 - 1s - loss: 0.0230 - val_loss: 0.0212 - 603ms/epoch - 24ms/step
# Epoch 12/40
# 25/25 - 1s - loss: 0.0210 - val_loss: 0.0217 - 573ms/epoch - 23ms/step
# Epoch 13/40
# 25/25 - 1s - loss: 0.0201 - val_loss: 0.0216 - 598ms/epoch - 24ms/step
# Epoch 14/40
# 25/25 - 1s - loss: 0.0207 - val_loss: 0.0274 - 583ms/epoch - 23ms/step
# Epoch 15/40
# 25/25 - 1s - loss: 0.0197 - val_loss: 0.0217 - 632ms/epoch - 25ms/step
# Epoch 16/40
# 25/25 - 1s - loss: 0.0182 - val_loss: 0.0258 - 602ms/epoch - 24ms/step
# Epoch 17/40
# 25/25 - 1s - loss: 0.0193 - val_loss: 0.0209 - 594ms/epoch - 24ms/step
# Epoch 18/40
# 25/25 - 1s - loss: 0.0176 - val_loss: 0.0224 - 609ms/epoch - 24ms/step
# Epoch 19/40
# 25/25 - 1s - loss: 0.0178 - val_loss: 0.0211 - 606ms/epoch - 24ms/step
# Epoch 20/40
# 25/25 - 1s - loss: 0.0199 - val_loss: 0.0211 - 630ms/epoch - 25ms/step
# Epoch 21/40
# 25/25 - 1s - loss: 0.0168 - val_loss: 0.0226 - 605ms/epoch - 24ms/step
# Epoch 22/40
# 25/25 - 1s - loss: 0.0161 - val_loss: 0.0244 - 578ms/epoch - 23ms/step
# Epoch 23/40
# 25/25 - 1s - loss: 0.0167 - val_loss: 0.0264 - 604ms/epoch - 24ms/step
# Epoch 24/40
# 25/25 - 1s - loss: 0.0159 - val_loss: 0.0199 - 774ms/epoch - 31ms/step
# Epoch 25/40
# 25/25 - 1s - loss: 0.0157 - val_loss: 0.0214 - 1s/epoch - 44ms/step
# Epoch 26/40
# 25/25 - 1s - loss: 0.0155 - val_loss: 0.0220 - 1s/epoch - 53ms/step
# Epoch 27/40
# 25/25 - 1s - loss: 0.0149 - val_loss: 0.0224 - 1s/epoch - 50ms/step
# Epoch 28/40
# 25/25 - 1s - loss: 0.0157 - val_loss: 0.0259 - 590ms/epoch - 24ms/step
# Epoch 29/40
# 25/25 - 1s - loss: 0.0149 - val_loss: 0.0231 - 577ms/epoch - 23ms/step
# Epoch 30/40
# 25/25 - 1s - loss: 0.0142 - val_loss: 0.0230 - 590ms/epoch - 24ms/step
# Epoch 31/40
# 25/25 - 1s - loss: 0.0154 - val_loss: 0.0220 - 588ms/epoch - 24ms/step
# Epoch 32/40
# 25/25 - 1s - loss: 0.0137 - val_loss: 0.0248 - 618ms/epoch - 25ms/step
# Epoch 33/40
# 25/25 - 1s - loss: 0.0138 - val_loss: 0.0249 - 618ms/epoch - 25ms/step
# Epoch 34/40
# 25/25 - 1s - loss: 0.0145 - val_loss: 0.0222 - 603ms/epoch - 24ms/step
# Epoch 35/40
# 25/25 - 1s - loss: 0.0137 - val_loss: 0.0252 - 603ms/epoch - 24ms/step
# Epoch 36/40
# 25/25 - 1s - loss: 0.0133 - val_loss: 0.0233 - 600ms/epoch - 24ms/step
# Epoch 37/40
# 25/25 - 1s - loss: 0.0139 - val_loss: 0.0260 - 592ms/epoch - 24ms/step
# Epoch 38/40
# 25/25 - 1s - loss: 0.0135 - val_loss: 0.0279 - 599ms/epoch - 24ms/step
# Epoch 39/40
# 25/25 - 1s - loss: 0.0134 - val_loss: 0.0245 - 576ms/epoch - 23ms/step
# Epoch 40/40
# 25/25 - 1s - loss: 0.0139 - val_loss: 0.0244 - 609ms/epoch - 24ms/step

# %% [markdown]
# #4. GRU

# %%
model_gru = Sequential()
model_gru.add(GRU(50, activation='relu', input_shape=(X_train_series.shape[1], X_train_series.shape[2])))
model_gru.add(Dense(y_train.shape[1]))

model_gru.compile(loss='mse', optimizer='adam')

# %%
gru_history = model_gru.fit(X_train_series, Y_train, validation_data=(X_valid_series, Y_valid), epochs=epochs, verbose=2)
# Out:
# Epoch 1/40
# 25/25 - 2s - loss: 0.2250 - val_loss: 0.0304 - 2s/epoch - 78ms/step
# Epoch 2/40
# 25/25 - 0s - loss: 0.0601 - val_loss: 0.0247 - 407ms/epoch - 16ms/step
# Epoch 3/40
# 25/25 - 0s - loss: 0.0436 - val_loss: 0.0224 - 400ms/epoch - 16ms/step
# Epoch 4/40
# 25/25 - 0s - loss: 0.0387 - val_loss: 0.0254 - 392ms/epoch - 16ms/step
# Epoch 5/40
# 25/25 - 0s - loss: 0.0359 - val_loss: 0.0218 - 404ms/epoch - 16ms/step
# Epoch 6/40
# 25/25 - 0s - loss: 0.0341 - val_loss: 0.0206 - 401ms/epoch - 16ms/step
# Epoch 7/40
# 25/25 - 0s - loss: 0.0328 - val_loss: 0.0255 - 402ms/epoch - 16ms/step
# Epoch 8/40
# 25/25 - 0s - loss: 0.0316 - val_loss: 0.0227 - 405ms/epoch - 16ms/step
# Epoch 9/40
# 25/25 - 0s - loss: 0.0304 - val_loss: 0.0214 - 398ms/epoch - 16ms/step
# Epoch 10/40
# 25/25 - 0s - loss: 0.0299 - val_loss: 0.0205 - 402ms/epoch - 16ms/step
# Epoch 11/40
# 25/25 - 0s - loss: 0.0290 - val_loss: 0.0215 - 392ms/epoch - 16ms/step
# Epoch 12/40
# 25/25 - 0s - loss: 0.0287 - val_loss: 0.0183 - 401ms/epoch - 16ms/step
# Epoch 13/40
# 25/25 - 0s - loss: 0.0275 - val_loss: 0.0190 - 445ms/epoch - 18ms/step
# Epoch 14/40
# 25/25 - 0s - loss: 0.0273 - val_loss: 0.0193 - 389ms/epoch - 16ms/step
# Epoch 15/40
# 25/25 - 0s - loss: 0.0259 - val_loss: 0.0179 - 395ms/epoch - 16ms/step
# Epoch 16/40
# 25/25 - 0s - loss: 0.0251 - val_loss: 0.0256 - 392ms/epoch - 16ms/step
# Epoch 17/40
# 25/25 - 0s - loss: 0.0244 - val_loss: 0.0189 - 394ms/epoch - 16ms/step
# Epoch 18/40
# 25/25 - 0s - loss: 0.0241 - val_loss: 0.0193 - 419ms/epoch - 17ms/step
# Epoch 19/40
# 25/25 - 0s - loss: 0.0238 - val_loss: 0.0183 - 372ms/epoch - 15ms/step
# Epoch 20/40
# 25/25 - 0s - loss: 0.0233 - val_loss: 0.0182 - 388ms/epoch - 16ms/step
# Epoch 21/40
# 25/25 - 0s - loss: 0.0218 - val_loss: 0.0179 - 388ms/epoch - 16ms/step
# Epoch 22/40
# 25/25 - 0s - loss: 0.0219 - val_loss: 0.0239 - 383ms/epoch - 15ms/step
# Epoch 23/40
# 25/25 - 0s - loss: 0.0209 - val_loss: 0.0191 - 373ms/epoch - 15ms/step
# Epoch 24/40
# 25/25 - 0s - loss: 0.0206 - val_loss: 0.0192 - 395ms/epoch - 16ms/step
# Epoch 25/40
# 25/25 - 0s - loss: 0.0200 - val_loss: 0.0195 - 391ms/epoch - 16ms/step
# Epoch 26/40
# 25/25 - 0s - loss: 0.0198 - val_loss: 0.0197 - 388ms/epoch - 16ms/step
# Epoch 27/40
# 25/25 - 0s - loss: 0.0193 - val_loss: 0.0189 - 374ms/epoch - 15ms/step
# Epoch 28/40
# 25/25 - 0s - loss: 0.0200 - val_loss: 0.0206 - 398ms/epoch - 16ms/step
# Epoch 29/40
# 25/25 - 0s - loss: 0.0213 - val_loss: 0.0213 - 396ms/epoch - 16ms/step
# Epoch 30/40
# 25/25 - 0s - loss: 0.0194 - val_loss: 0.0193 - 403ms/epoch - 16ms/step
# Epoch 31/40
# 25/25 - 0s - loss: 0.0204 - val_loss: 0.0192 - 391ms/epoch - 16ms/step
# Epoch 32/40
# 25/25 - 0s - loss: 0.0185 - val_loss: 0.0204 - 377ms/epoch - 15ms/step
# Epoch 33/40
# 25/25 - 0s - loss: 0.0191 - val_loss: 0.0216 - 393ms/epoch - 16ms/step
# Epoch 34/40
# 25/25 - 0s - loss: 0.0191 - val_loss: 0.0199 - 391ms/epoch - 16ms/step
# Epoch 35/40
# 25/25 - 0s - loss: 0.0185 - val_loss: 0.0197 - 398ms/epoch - 16ms/step
# Epoch 36/40
# 25/25 - 0s - loss: 0.0186 - val_loss: 0.0200 - 382ms/epoch - 15ms/step
# Epoch 37/40
# 25/25 - 0s - loss: 0.0186 - val_loss: 0.0214 - 409ms/epoch - 16ms/step
# Epoch 38/40
# 25/25 - 0s - loss: 0.0179 - val_loss: 0.0203 - 392ms/epoch - 16ms/step
# Epoch 39/40
# 25/25 - 0s - loss: 0.0178 - val_loss: 0.0194 - 422ms/epoch - 17ms/step
# Epoch 40/40
# 25/25 - 0s - loss: 0.0180 - val_loss: 0.0187 - 400ms/epoch - 16ms/step

# %% [markdown]
# #5. CNN-LSTM
# * Input shape **[samples, subsequences, timesteps, features]**.
#
#
# > "The benefit of this model is that the model can support very long input sequences that can be read as blocks or subsequences by the CNN model, then pieced together by the LSTM model."
# >
# > "When using a hybrid CNN-LSTM model, we will further divide each sample into further subsequences. The CNN model will interpret each sub-sequence and the LSTM will piece together the interpretations from the subsequences. As such, we will split each sample into 2 subsequences of 2 times per subsequence."
# >
# > "The CNN will be defined to expect 2 timesteps per subsequence with one feature. The entire CNN model is then wrapped in TimeDistributed wrapper layers so that it can be applied to each subsequence in the sample. The results are then interpreted by the LSTM layer before the model outputs a prediction."
#
# #### Data preprocess
# * Reshape from [samples, timesteps, features] into [samples, subsequences, timesteps, features].

# %%
X_train_series_sub = X_train_series.reshape((798,2,135,1))
X_valid_series_sub = X_valid_series.reshape((177,2,135,1))
print('Train set shape', X_train_series_sub.shape)
print('Validation set shape', X_valid_series_sub.shape)
# Out:
# Train set shape (798, 2, 135, 1)
# Validation set shape (177, 2, 135, 1)

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D , MaxPooling1D , LSTM, TimeDistributed, Flatten, Bidirectional

model_cnn_lstm = Sequential()
model_cnn_lstm.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'), input_shape=(None, X_train_series_sub.shape[2], X_train_series_sub.shape[3])))
model_cnn_lstm.add(TimeDistributed(Conv1D(filters=128, kernel_size=2)))
model_cnn_lstm.add(TimeDistributed(MaxPooling1D(pool_size=2)))
model_cnn_lstm.add(TimeDistributed(Flatten()))
model_cnn_lstm.add(LSTM(50, activation='relu'))
model_cnn_lstm.add(Dense(32))
model_cnn_lstm.add(Dense(1))
model_cnn_lstm.compile(loss='mse', optimizer=adam)

# %%
cnn_lstm_history = model_cnn_lstm.fit(X_train_series_sub, Y_train, validation_data=(X_valid_series_sub, Y_valid), epochs=epochs, verbose=2)
# Out:
# Epoch 1/40
# 25/25 - 4s - loss: 0.0799 - val_loss: 0.0246 - 4s/epoch - 150ms/step
# Epoch 2/40
# 25/25 - 2s - loss: 0.0439 - val_loss: 0.0266 - 2s/epoch - 64ms/step
# Epoch 3/40
# 25/25 - 3s - loss: 0.0345 - val_loss: 0.0271 - 3s/epoch - 107ms/step
# Epoch 4/40
# 25/25 - 3s - loss: 0.0318 - val_loss: 0.0283 - 3s/epoch - 121ms/step
# Epoch 5/40
# 25/25 - 3s - loss: 0.0284 - val_loss: 0.0376 - 3s/epoch - 129ms/step
# Epoch 6/40
# 25/25 - 3s - loss: 0.0266 - val_loss: 0.0392 - 3s/epoch - 120ms/step
# Epoch 7/40
# 25/25 - 3s - loss: 0.0258 - val_loss: 0.0278 - 3s/epoch - 121ms/step
# Epoch 8/40
# 25/25 - 3s - loss: 0.0221 - val_loss: 0.0353 - 3s/epoch - 124ms/step
# Epoch 9/40
# 25/25 - 3s - loss: 0.0208 - val_loss: 0.0328 - 3s/epoch - 123ms/step
# Epoch 10/40
# 25/25 - 3s - loss: 0.0205 - val_loss: 0.0301 - 3s/epoch - 129ms/step
# Epoch 11/40
# 25/25 - 2s - loss: 0.0191 - val_loss: 0.0293 - 2s/epoch - 92ms/step
# Epoch 12/40
# 25/25 - 2s - loss: 0.0180 - val_loss: 0.0316 - 2s/epoch - 63ms/step
# Epoch 13/40
# 25/25 - 2s - loss: 0.0176 - val_loss: 0.0291 - 2s/epoch - 62ms/step
# Epoch 14/40
# 25/25 - 2s - loss: 0.0180 - val_loss: 0.0367 - 2s/epoch - 62ms/step
# Epoch 15/40
# 25/25 - 2s - loss: 0.0172 - val_loss: 0.0331 - 2s/epoch - 64ms/step
# Epoch 16/40
# 25/25 - 2s - loss: 0.0158 - val_loss: 0.0419 - 2s/epoch - 62ms/step
# Epoch 17/40
# 25/25 - 2s - loss: 0.0152 - val_loss: 0.0339 - 2s/epoch - 63ms/step
# Epoch 18/40
# 25/25 - 2s - loss: 0.0146 - val_loss: 0.0339 - 2s/epoch - 61ms/step
# Epoch 19/40
# 25/25 - 2s - loss: 0.0146 - val_loss: 0.0451 - 2s/epoch - 63ms/step
# Epoch 20/40
# 25/25 - 2s - loss: 0.0155 - val_loss: 0.0473 - 2s/epoch - 62ms/step
# Epoch 21/40
# 25/25 - 2s - loss: 0.0125 - val_loss: 0.0350 - 2s/epoch - 63ms/step
# Epoch 22/40
# 25/25 - 2s - loss: 0.0123 - val_loss: 0.0406 - 2s/epoch - 62ms/step
# Epoch 23/40
# 25/25 - 2s - loss: 0.0121 - val_loss: 0.0369 - 2s/epoch - 62ms/step
# Epoch 24/40
# 25/25 - 2s - loss: 0.0111 - val_loss: 0.0321 - 2s/epoch - 62ms/step
# Epoch 25/40
# 25/25 - 2s - loss: 0.0105 - val_loss: 0.0433 - 2s/epoch - 63ms/step
# Epoch 26/40
# 25/25 - 2s - loss: 0.0103 - val_loss: 0.0335 - 2s/epoch - 62ms/step
# Epoch 27/40
# 25/25 - 2s - loss: 0.0097 - val_loss: 0.0356 - 2s/epoch - 62ms/step
# Epoch 28/40
# 25/25 - 2s - loss: 0.0090 - val_loss: 0.0407 - 2s/epoch - 64ms/step
# Epoch 29/40
# 25/25 - 2s - loss: 0.0091 - val_loss: 0.0394 - 2s/epoch - 62ms/step
# Epoch 30/40
# 25/25 - 2s - loss: 0.0084 - val_loss: 0.0323 - 2s/epoch - 61ms/step
# Epoch 31/40
# 25/25 - 2s - loss: 0.0083 - val_loss: 0.0384 - 2s/epoch - 62ms/step
# Epoch 32/40
# 25/25 - 2s - loss: 0.0075 - val_loss: 0.0423 - 2s/epoch - 62ms/step
# Epoch 33/40
# 25/25 - 2s - loss: 0.0071 - val_loss: 0.0311 - 2s/epoch - 62ms/step
# Epoch 34/40
# 25/25 - 2s - loss: 0.0073 - val_loss: 0.0397 - 2s/epoch - 61ms/step
# Epoch 35/40
# 25/25 - 2s - loss: 0.0068 - val_loss: 0.0335 - 2s/epoch - 63ms/step
# Epoch 36/40
# 25/25 - 2s - loss: 0.0063 - val_loss: 0.0385 - 2s/epoch - 63ms/step
# Epoch 37/40
# 25/25 - 2s - loss: 0.0059 - val_loss: 0.0380 - 2s/epoch - 63ms/step
# Epoch 38/40
# 25/25 - 2s - loss: 0.0063 - val_loss: 0.0407 - 2s/epoch - 62ms/step
# Epoch 39/40
# 25/25 - 2s - loss: 0.0058 - val_loss: 0.0460 - 2s/epoch - 63ms/step
# Epoch 40/40
# 25/25 - 2s - loss: 0.0054 - val_loss: 0.0372 - 2s/epoch - 62ms/step

# %% [markdown]
# #6. CNN-BiLSTM

# %%
model_cnn_bilstm = Sequential()
model_cnn_bilstm.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'), input_shape=(None, X_train_series_sub.shape[2], X_train_series_sub.shape[3])))
model_cnn_bilstm.add(TimeDistributed(Conv1D(filters=128, kernel_size=2)))
model_cnn_bilstm.add(TimeDistributed(MaxPooling1D(pool_size=2)))
model_cnn_bilstm.add(TimeDistributed(Flatten()))
model_cnn_bilstm.add(Bidirectional(LSTM(50, activation='relu')))
model_cnn_bilstm.add(Dense(32))
model_cnn_bilstm.add(Dense(1))
model_cnn_bilstm.compile(loss='mse', optimizer=adam)

# %%
cnn_bilstm_history = model_cnn_bilstm.fit(X_train_series_sub, Y_train, validation_data=(X_valid_series_sub, Y_valid), epochs=epochs, verbose=2)

# %% [markdown]
# #7. CNN-GRU

# %%
model_cnn_gru = Sequential()
model_cnn_gru.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'), input_shape=(None, X_train_series_sub.shape[2], X_train_series_sub.shape[3])))
model_cnn_gru.add(TimeDistributed(Conv1D(filters=128, kernel_size=2)))
model_cnn_gru.add(TimeDistributed(MaxPooling1D(pool_size=2)))
model_cnn_gru.add(TimeDistributed(Flatten()))
model_cnn_gru.add(GRU(50, activation='relu'))
model_cnn_gru.add(Dense(32))
model_cnn_gru.add(Dense(1))
model_cnn_gru.compile(loss='mse', optimizer=adam)

# %%
cnn_gru_history = model_cnn_gru.fit(X_train_series_sub, Y_train, validation_data=(X_valid_series_sub, Y_valid), epochs=epochs, verbose=2)
# Out:
# Epoch 1/40
# 25/25 - 5s - loss: 0.0928 - val_loss: 0.0663 - 5s/epoch - 201ms/step
# Epoch 2/40
# 25/25 - 2s - loss: 0.0381 - val_loss: 0.0261 - 2s/epoch - 61ms/step
# Epoch 3/40
# 25/25 - 2s - loss: 0.0337 - val_loss: 0.0240 - 2s/epoch - 61ms/step
# Epoch 4/40
# 25/25 - 1s - loss: 0.0329 - val_loss: 0.0203 - 1s/epoch - 60ms/step
# Epoch 5/40
# 25/25 - 2s - loss: 0.0291 - val_loss: 0.0216 - 2s/epoch - 61ms/step
# Epoch 6/40
# 25/25 - 3s - loss: 0.0263 - val_loss: 0.0240 - 3s/epoch - 106ms/step
# Epoch 7/40
# 25/25 - 2s - loss: 0.0238 - val_loss: 0.0202 - 2s/epoch - 61ms/step
# Epoch 8/40
# 25/25 - 1s - loss: 0.0206 - val_loss: 0.0337 - 1s/epoch - 60ms/step
# Epoch 9/40
# 25/25 - 3s - loss: 0.0186 - val_loss: 0.0270 - 3s/epoch - 102ms/step
# Epoch 10/40
# 25/25 - 2s - loss: 0.0178 - val_loss: 0.0257 - 2s/epoch - 60ms/step
# Epoch 11/40
# 25/25 - 3s - loss: 0.0165 - val_loss: 0.0204 - 3s/epoch - 115ms/step
# Epoch 12/40
# 25/25 - 2s - loss: 0.0151 - val_loss: 0.0264 - 2s/epoch - 87ms/step
# Epoch 13/40
# 25/25 - 2s - loss: 0.0144 - val_loss: 0.0210 - 2s/epoch - 89ms/step
# Epoch 14/40
# 25/25 - 3s - loss: 0.0144 - val_loss: 0.0288 - 3s/epoch - 104ms/step
# Epoch 15/40
# 25/25 - 3s - loss: 0.0133 - val_loss: 0.0206 - 3s/epoch - 111ms/step
# Epoch 16/40
# 25/25 - 3s - loss: 0.0123 - val_loss: 0.0217 - 3s/epoch - 128ms/step
# Epoch 17/40
# 25/25 - 3s - loss: 0.0119 - val_loss: 0.0240 - 3s/epoch - 109ms/step
# Epoch 18/40
# 25/25 - 2s - loss: 0.0121 - val_loss: 0.0228 - 2s/epoch - 77ms/step
# Epoch 19/40
# 25/25 - 3s - loss: 0.0111 - val_loss: 0.0229 - 3s/epoch - 119ms/step
# Epoch 20/40
# 25/25 - 2s - loss: 0.0112 - val_loss: 0.0225 - 2s/epoch - 83ms/step
# Epoch 21/40
# 25/25 - 2s - loss: 0.0096 - val_loss: 0.0284 - 2s/epoch - 80ms/step
# Epoch 22/40
# 25/25 - 2s - loss: 0.0091 - val_loss: 0.0219 - 2s/epoch - 96ms/step
# Epoch 23/40
# 25/25 - 3s - loss: 0.0088 - val_loss: 0.0229 - 3s/epoch - 103ms/step
# Epoch 24/40
# 25/25 - 3s - loss: 0.0083 - val_loss: 0.0242 - 3s/epoch - 113ms/step
# Epoch 25/40
# 25/25 - 2s - loss: 0.0077 - val_loss: 0.0228 - 2s/epoch - 64ms/step
# Epoch 26/40
# 25/25 - 2s - loss: 0.0075 - val_loss: 0.0406 - 2s/epoch - 89ms/step
# Epoch 27/40
# 25/25 - 3s - loss: 0.0070 - val_loss: 0.0239 - 3s/epoch - 135ms/step
# Epoch 28/40
# 25/25 - 2s - loss: 0.0067 - val_loss: 0.0237 - 2s/epoch - 87ms/step
# Epoch 29/40
# 25/25 - 3s - loss: 0.0063 - val_loss: 0.0250 - 3s/epoch - 120ms/step
# Epoch 30/40
# 25/25 - 2s - loss: 0.0056 - val_loss: 0.0383 - 2s/epoch - 61ms/step
# Epoch 31/40
# 25/25 - 1s - loss: 0.0052 - val_loss: 0.0244 - 1s/epoch - 59ms/step
# Epoch 32/40
# 25/25 - 2s - loss: 0.0049 - val_loss: 0.0247 - 2s/epoch - 60ms/step
# Epoch 33/40
# 25/25 - 2s - loss: 0.0044 - val_loss: 0.0347 - 2s/epoch - 60ms/step
# Epoch 34/40
# 25/25 - 2s - loss: 0.0042 - val_loss: 0.0359 - 2s/epoch - 60ms/step
# Epoch 35/40
# 25/25 - 1s - loss: 0.0041 - val_loss: 0.0363 - 1s/epoch - 60ms/step
# Epoch 36/40
# 25/25 - 2s - loss: 0.0038 - val_loss: 0.0251 - 2s/epoch - 60ms/step
# Epoch 37/40
# 25/25 - 2s - loss: 0.0036 - val_loss: 0.0250 - 2s/epoch - 60ms/step
# Epoch 38/40
# 25/25 - 2s - loss: 0.0033 - val_loss: 0.0391 - 2s/epoch - 61ms/step
# Epoch 39/40
# 25/25 - 2s - loss: 0.0030 - val_loss: 0.0311 - 2s/epoch - 91ms/step
# Epoch 40/40
# 25/25 - 2s - loss: 0.0028 - val_loss: 0.0407 - 2s/epoch - 77ms/step

# %% [markdown]
# #**Comparing models**

# %%
fig, axes = plt.subplots(4, 2, sharex=True, sharey=True,figsize=(22, 20))
ax1, ax2 = axes[0]
ax3, ax4 = axes[1]
ax5, ax6 = axes[2]
ax7, ax8 = axes[3]

ax1.plot(cnn_history.history['loss'], label='Train loss')
ax1.plot(cnn_history.history['val_loss'], label='Validation loss')
ax1.legend(loc='best')
ax1.set_title('CNN')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('MSE')

ax2.plot(lstm_history.history['loss'], label='Train loss')
ax2.plot(lstm_history.history['val_loss'], label='Validation loss')
ax2.legend(loc='best')
ax2.set_title('LSTM')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('MSE')

ax3.plot(bilstm_history.history['loss'], label='Train loss')
ax3.plot(bilstm_history.history['val_loss'], label='Validation loss')
ax3.legend(loc='best')
ax3.set_title('BiLSTM')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('MSE')

ax4.plot(gru_history.history['loss'], label='Train loss')
ax4.plot(gru_history.history['val_loss'], label='Validation loss')
ax4.legend(loc='best')
ax4.set_title('GRU')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('MSE')

ax5.plot(cnn_lstm_history.history['loss'], label='Train loss')
ax5.plot(cnn_lstm_history.history['val_loss'], label='Validation loss')
ax5.legend(loc='best')
ax5.set_title('CNN-LSTM')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('MSE')

ax6.plot(cnn_bilstm_history.history['loss'], label='Train loss')
ax6.plot(cnn_bilstm_history.history['val_loss'], label='Validation loss')
ax6.legend(loc='best')
ax6.set_title('CNN-BiLSTM')
ax6.set_xlabel('Epochs')
ax6.set_ylabel('MSE')

ax7.plot(cnn_gru_history.history['loss'], label='Train loss')
ax7.plot(cnn_gru_history.history['val_loss'], label='Validation loss')
ax7.legend(loc='best')
ax7.set_title('CNN-GRU')
ax7.set_xlabel('Epochs')
ax7.set_ylabel('MSE')

ax8.plot(cnn_gru_history.history['loss'], label='Train loss')


plt.show()

# %% [markdown]
# #**MODEL EVALUATION**

# %% [markdown]
# ## CNN on train and validation

# %%
cnn_train_pred = model_cnn.predict(X_train_series)
cnn_valid_pred = model_cnn.predict(X_valid_series)
print('Train rmse:', np.sqrt(mean_squared_error(Y_train, cnn_train_pred)))
print('Validation rmse:', np.sqrt(mean_squared_error(Y_valid, cnn_valid_pred)))
# Out:
# 25/25 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 4ms/step
# Train rmse: 0.08440708152796554
# Validation rmse: 0.15369303397150494

# %% [markdown]
# ## LSTM on train and validation

# %%
lstm_train_pred = model_lstm.predict(X_train_series)
lstm_valid_pred = model_lstm.predict(X_valid_series)
print('Train rmse:', np.sqrt(mean_squared_error(Y_train, lstm_train_pred)))
print('Validation rmse:', np.sqrt(mean_squared_error(Y_valid, lstm_valid_pred)))
# Out:
# 25/25 [==============================] - 0s 6ms/step
# 6/6 [==============================] - 0s 8ms/step
# Train rmse: 0.13224255105449445
# Validation rmse: 0.15605289953890955

# %% [markdown]
# ##BiLSTM on train and validation

# %%
bilstm_train_pred = model_bilstm.predict(X_train_series)
bilstm_valid_pred = model_bilstm.predict(X_valid_series)
print('Train rmse:', np.sqrt(mean_squared_error(Y_train, bilstm_train_pred)))
print('Validation rmse:', np.sqrt(mean_squared_error(Y_valid, bilstm_valid_pred)))
# Out:
# 25/25 [==============================] - 0s 8ms/step
# 6/6 [==============================] - 0s 7ms/step
# Train rmse: 0.1102354644493263
# Validation rmse: 0.15630897375904118

# %% [markdown]
# ##GRU on train and validation

# %%
gru_train_pred = model_gru.predict(X_train_series)
gru_valid_pred = model_gru.predict(X_valid_series)
print('Train rmse:', np.sqrt(mean_squared_error(Y_train, gru_train_pred)))
print('Validation rmse:', np.sqrt(mean_squared_error(Y_valid, gru_valid_pred)))
# Out:
# 25/25 [==============================] - 0s 5ms/step
# 6/6 [==============================] - 0s 5ms/step
# Train rmse: 0.1316143056004934
# Validation rmse: 0.13665777996594142

# %% [markdown]
# ## CNN-LSTM on train and validation

# %%
cnn_lstm_train_pred = model_cnn_lstm.predict(X_train_series_sub)
cnn_lstm_valid_pred = model_cnn_lstm.predict(X_valid_series_sub)
print('Train rmse:', np.sqrt(mean_squared_error(Y_train, cnn_lstm_train_pred)))
print('Validation rmse:', np.sqrt(mean_squared_error(Y_valid, cnn_lstm_valid_pred)))
# Out:
# 25/25 [==============================] - 1s 16ms/step
# 6/6 [==============================] - 0s 15ms/step
# Train rmse: 0.07038491651693338
# Validation rmse: 0.1928032383650875

# %% [markdown]
# ##CNN-BiLSTM on train and validation

# %%
cnn_bilstm_train_pred = model_cnn_bilstm.predict(X_train_series_sub)
cnn_bilstm_valid_pred = model_cnn_bilstm.predict(X_valid_series_sub)
print('Train rmse:', np.sqrt(mean_squared_error(Y_train, cnn_bilstm_train_pred)))
print('Validation rmse:', np.sqrt(mean_squared_error(Y_valid, cnn_bilstm_valid_pred)))
# Out:
# 25/25 [==============================] - 1s 23ms/step
# 6/6 [==============================] - 0s 21ms/step
# Train rmse: 0.050467292105862455
# Validation rmse: 0.15441656140441118

# %% [markdown]
# ##CNN-GRU on train and validation

# %%
cnn_gru_train_pred = model_cnn_gru.predict(X_train_series_sub)
cnn_gru_valid_pred = model_cnn_gru.predict(X_valid_series_sub)
print('Train rmse:', np.sqrt(mean_squared_error(Y_train, cnn_gru_train_pred)))
print('Validation rmse:', np.sqrt(mean_squared_error(Y_valid, cnn_gru_valid_pred)))
# Out:
# 25/25 [==============================] - 1s 16ms/step
# 6/6 [==============================] - 0s 19ms/step
# Train rmse: 0.05219001905197763
# Validation rmse: 0.201752126293913

# %% [markdown]
# # **TRUE VS PREDICTION**

# %% [markdown]
# ## CNN true future vs prediction

# %%
def plot_future(Y_valid):
    
    plt.figure(figsize=(10, 6))
    
    range_future = len(cnn_valid_pred)

    plt.plot(np.arange(range_future), np.array(Y_valid), label='True Future')
    plt.plot(np.arange(range_future), np.array(cnn_valid_pred),label='Prediction')

    plt.title('True future vs prediction for ' + "CNN")
    plt.legend(loc='upper left')
    plt.xlabel('Time (day)')
    plt.ylabel('PM 10 Value')
    #plt.savefig('C:/Users/nious/Documents/Medium/LSTM&GRU/predic_'+model_name+'.jpg', format='jpg', dpi=1000)

plot_future(Y_valid)

# %% [markdown]
# ## LSTM true future vs prediction

# %%
def plot_future(Y_valid):
    
    plt.figure(figsize=(10, 6))
    
    range_future = len(lstm_valid_pred)

    plt.plot(np.arange(range_future), np.array(Y_valid), label='True Future')
    plt.plot(np.arange(range_future), np.array(lstm_valid_pred),label='Prediction')

    plt.title('True future vs prediction for ' + "LSTM")
    plt.legend(loc='upper left')
    plt.xlabel('Time (day)')
    plt.ylabel('PM 10 Value')
    #plt.savefig('C:/Users/nious/Documents/Medium/LSTM&GRU/predic_'+model_name+'.jpg', format='jpg', dpi=1000)

plot_future(Y_valid)

# %% [markdown]
# ## Bi-LSTM true future vs prediction

# %%
def plot_future(Y_valid):
    
    plt.figure(figsize=(10, 6))
  
    range_future = len(bilstm_valid_pred)

    plt.plot(np.arange(range_future), np.array(Y_valid), label='True Future')
    plt.plot(np.arange(range_future), np.array(bilstm_valid_pred),label='Prediction')

    plt.title('True future vs prediction for ' + "BiLSTM")
    plt.legend(loc='upper left')
    plt.xlabel('Time (day)')
    plt.ylabel('PM 10 Value')
    #plt.savefig('C:/Users/nious/Documents/Medium/LSTM&GRU/predic_'+model_name+'.jpg', format='jpg', dpi=1000)

plot_future(Y_valid)

# %% [markdown]
# ## GRU true future vs prediction

# %%
def plot_future(Y_valid):
    
    plt.figure(figsize=(10, 6))
    
    range_future = len(gru_valid_pred)

    plt.plot(np.arange(range_future), np.array(Y_valid), label='True Future')
    plt.plot(np.arange(range_future), np.array(gru_valid_pred),label='Prediction')

    plt.title('True future vs prediction for ' + "GRU")
    plt.legend(loc='upper left')
    plt.xlabel('Time (day)')
    plt.ylabel('PM 10 Value')
    #plt.savefig('C:/Users/nious/Documents/Medium/LSTM&GRU/predic_'+model_name+'.jpg', format='jpg', dpi=1000)

plot_future(Y_valid)

# %% [markdown]
# ## CNN-LSTM true future vs prediction

# %%
def plot_future(Y_valid):
    
    plt.figure(figsize=(10, 6))
    
    range_future = len(cnn_lstm_valid_pred)

    plt.plot(np.arange(range_future), np.array(Y_valid), label='True Future')
    plt.plot(np.arange(range_future), np.array(cnn_lstm_valid_pred),label='Prediction')

    plt.title('True future vs prediction for ' + "CNN-LSTM")
    plt.legend(loc='upper left')
    plt.xlabel('Time (day)')
    plt.ylabel('PM 10 Value')
    #plt.savefig('C:/Users/nious/Documents/Medium/LSTM&GRU/predic_'+model_name+'.jpg', format='jpg', dpi=1000)

plot_future(Y_valid)

# %% [markdown]
# ## CNN-BiLSTM true future vs prediction

# %%
def plot_future(Y_valid):
    
    plt.figure(figsize=(10, 6))
    
    range_future = len(cnn_bilstm_valid_pred)

    plt.plot(np.arange(range_future), np.array(Y_valid), label='True Future')
    plt.plot(np.arange(range_future), np.array(cnn_bilstm_valid_pred),label='Prediction')

    plt.title('True future vs prediction for ' + "CNN-BiLSTM")
    plt.legend(loc='upper left')
    plt.xlabel('Time (day)')
    plt.ylabel('PM 10 Value')
    #plt.savefig('C:/Users/nious/Documents/Medium/LSTM&GRU/predic_'+model_name+'.jpg', format='jpg', dpi=1000)

plot_future(Y_valid)

# %% [markdown]
# ## CNN-GRU true future vs prediction

# %%
def plot_future(Y_valid):
    
    plt.figure(figsize=(10, 6))
    
    range_future = len(cnn_gru_valid_pred)

    plt.plot(np.arange(range_future), np.array(Y_valid), label='True Future')
    plt.plot(np.arange(range_future), np.array(cnn_gru_valid_pred),label='Prediction')

    plt.title('True future vs prediction for ' + "CNN-GRU")
    plt.legend(loc='upper left')
    plt.xlabel('Time (day)')
    plt.ylabel('PM 10 Value')
    #plt.savefig('C:/Users/nious/Documents/Medium/LSTM&GRU/predic_'+model_name+'.jpg', format='jpg', dpi=1000)

plot_future(Y_valid)

# %% [markdown]
# #**FORECASTING**

# %%
# Import climate data projection
newinput = pd.read_csv('drive/MyDrive/Colab Notebooks/check.csv', parse_dates=['date'], index_col = 'date')

# Order of the variable are important
X_new = newinput.loc['2020-01-01':'2020-11-01',:] 
X_new
# Out:
#             PM2dot5      NO     NO2     NOx    NH3    SO2    CO  Ozone  \
# date
# 2020-01-01   463.70  138.69  187.54  221.16  84.05   8.03  3.01   4.45
# 2020-01-02   468.71  154.67  175.03  242.23  94.45   9.94  3.56   3.38
# 2020-01-03   442.17  132.56  182.31  254.12  97.50   9.48  2.89   4.36
# 2020-01-04   465.35  114.51  192.79  239.20  89.46   7.36  2.53   3.59
# 2020-01-05   360.12   74.52  179.69  156.32  79.28    NaN  1.74   2.82
# ...             ...     ...     ...     ...    ...    ...   ...    ...
# 2020-10-28   491.30   76.29   93.24  112.38  29.82  14.84  1.83  59.50
# 2020-10-29   564.98   88.86  108.13  161.25  37.01   9.73  2.19  28.58
# 2020-10-30   512.80   54.78   78.04   86.17  29.58   4.14  1.63   2.02
# 2020-10-31   551.28   22.36   74.18   57.16  29.63   8.84  1.44  21.78
# 2020-11-01   537.42   23.66   75.74   59.56   1.18  14.61  1.35  29.80
#
#             Wind speed
# date
# 2020-01-01        0.38
# 2020-01-02        0.22
# 2020-01-03        0.38
# 2020-01-04        0.28
# 2020-01-05        0.35
# ...                ...
# 2020-10-28        0.20
# 2020-10-29        0.14
# 2020-10-30        0.27
# 2020-10-31        0.35
# 2020-11-01        0.31
#
# [306 rows x 9 columns]

# %%
# Plot histoy and future data
def plot_history_future(Y_train, model):
    
    plt.figure(figsize=(10, 6))
    
    range_history = len(Y_train)
    range_future = list(range(range_history, range_history + len(model)))

    plt.plot(np.arange(range_history), np.array(Y_train), label='History')
    plt.plot(range_future, np.array(model),label='Prediction')

    plt.title('History and prediction for the best performing model')
    plt.legend(loc='upper right')
    plt.xlabel('Time (day)')
    plt.ylabel('PM 10 Value')
    #plt.savefig('C:/Users/nious/Documents/Medium/LSTM&GRU/3.jpg', format='jpg', dpi=1000)

# %%
def forecast(X_input, time_steps, model_name):
    X = input_scaler.transform(X_input)
    X = X_input
    Xs = []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:i+time_steps, :]
        Xs.append(v)
        
    X_transformed = np.array(Xs)
    prediction_actual = model_name.predict(X_transformed)
    return prediction_actual

# %% [markdown]
# # CNN Forecast

# %%
prediction_actual = forecast(X_new, TIME_STEPS, model_cnn)
plot_history_future(Y_train, cnn_valid_pred)
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %% [markdown]
# # LSTM Forecast

# %%
prediction_actual = forecast(X_new, TIME_STEPS, model_lstm)
plot_history_future(Y_train, lstm_valid_pred)
# Out:
# 9/9 [==============================] - 0s 9ms/step

# %% [markdown]
# # BiLSTM Forecast

# %%
prediction_actual = forecast(X_new, TIME_STEPS, model_bilstm)
plot_history_future(Y_train, bilstm_valid_pred)
# Out:
# 9/9 [==============================] - 0s 8ms/step

# %% [markdown]
# # GRU Forecast

# %%
prediction_actual = forecast(X_new, TIME_STEPS, model_gru)
plot_history_future(Y_train, gru_valid_pred)
# Out:
# 9/9 [==============================] - 0s 16ms/step

# %% [markdown]
# # Hybrid Forecast
